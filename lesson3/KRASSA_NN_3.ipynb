# %% [markdown]
# ## Решение домашнего задания к уроку 3. TensorFlow

# %% [markdown]
# ### Задание:
# #### Используя файл Web3.ipynb (он в полезных ссылках):
#
# Постройте нейронную сеть (берем несложную полносвязную сеть, меняем число слоев, число нейронов, типы активации, тип оптимизатора) на датасете from sklearn.datasets import load_boston.
#
# Постройте 10-15 вариантов разных нейронных сетей и сведите результаты их работы в таблицу. Опишите, какого результата вы добились от нейросети? Что помогло вам улучшить ее точность?

# %%
pip install scikit-learn==1.1.3
# Out:
# Requirement already satisfied: scikit-learn==1.1.3 in /usr/local/lib/python3.10/dist-packages (1.1.3)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.1.3) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.1.3) (1.10.1)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.1.3) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.1.3) (3.1.0)

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx
import seaborn as sns
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from tensorflow.keras.layers import Input, Flatten, Dense
from tensorflow.keras.models import Sequential, Model

# %matplotlib inline

# %%
tf.random.set_seed(1)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
boston_dataset = load_boston()
print(boston_dataset.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#   warnings.warn(msg, category=FutureWarning)

# %%
boston = pd.DataFrame(boston_dataset.data, columns=boston_dataset.feature_names)
boston['target'] = boston_dataset.target
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  target   506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT      target
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
X = boston.drop(['target'], axis=1)
y = boston['target']

# %%
corr_with_target = boston.corr().iloc[:-1, -1].sort_values(ascending=False)

plt.figure(figsize=(10, 8))

sns.barplot(x=corr_with_target.values, y=corr_with_target.index)

plt.title('Correlation with target variable')
plt.show()

# %%
# Масштабирование
X_sc = StandardScaler().fit(X).transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sc, y, test_size = 0.3, random_state=0)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (354, 13)
# (152, 13)
# (354,)
# (152,)

# %%
results = pd.DataFrame() # сводная таблица результатов
n_layers = [] # число слоев
n_nums = [] # число нейронов
act_func = [] # функция активации
opt = [] # оптимизатор
train_mse = [] # ошибка на тренировочной выборке
test_mse = [] # ошибка на тестовой выборке

# %% [markdown]
# Будем проверять следующие значения:<br>
# n_layers: 3, 5 и 10 <br>
# n_nums: 8, 32 и 128 <br>
# act_func: ReLU, sigmoid и tanh <br>
# opt: RMSProp и Adam<br>

# %%
# Рассмотрим 3-слойную сеть
fig = plt.figure(figsize=(30,20))
plt.subplots_adjust(wspace=0.1, hspace=0.5)
k = 0
for n in [8, 32, 128]:
  for f in ['relu', 'sigmoid', 'tanh']:
    k += 1
    for o in ['RMSprop', 'Adam']:
      n_layers.append(3)
      n_nums.append(n)
      act_func.append(f)
      opt.append(o)

      print(f'\nПараметры текущей нейронной сети: 3 слоя, {n} нейронов, функция активации {f}, оптимизатор {o}...')

      inputs = Input(shape=(13,))
      x_1 = Flatten()(inputs)
      x_2 = Dense(n, activation=f)(x_1)
      outputs = Dense(1)(x_2)

      model = Model(inputs, outputs)

      model.compile(optimizer=o,
                    loss='mse',
                    metrics=['mse'])

      #model.summary()

      history = model.fit(X_train, y_train,
                    epochs=10,
                    batch_size=5,
                    validation_data=(X_test, y_test),
                    verbose=0)

      train_loss, train_m = model.evaluate(X_train, y_train, verbose=2)
      test_loss, test_m = model.evaluate(X_test, y_test, verbose=2)
      train_mse.append(train_m)
      test_mse.append(test_m)

      ax = fig.add_subplot(6, 2, k)
      ax.plot(history.history['val_mse'], label=f'val {o} {round(test_m,2)}')
      ax.plot(history.history['mse'], label=f'train {o} {round(train_m,2)}')
      ax.legend()
      ax.set_xlabel('epoch')
      ax.set_ylabel('mse')
      ax.set(title = f'Ошибка сети от эпох при {n} нейронах и функции активации {f}')
plt.show()
# Out:
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 333.8351 - mse: 333.8351 - 68ms/epoch - 6ms/step
# 5/5 - 0s - loss: 320.7763 - mse: 320.7763 - 46ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 286.9367 - mse: 286.9367 - 88ms/epoch - 7ms/step
# 5/5 - 0s - loss: 272.4355 - mse: 272.4355 - 41ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 387.1880 - mse: 387.1880 - 37ms/epoch - 3ms/step
# 5/5 - 0s - loss: 368.2928 - mse: 368.2928 - 25ms/epoch - 5ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 452.3080 - mse: 452.3080 - 43ms/epoch - 4ms/step
# 5/5 - 0s - loss: 427.8306 - mse: 427.8306 - 28ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 411.5978 - mse: 411.5978 - 39ms/epoch - 3ms/step
# 5/5 - 0s - loss: 400.8471 - mse: 400.8471 - 26ms/epoch - 5ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 373.5674 - mse: 373.5674 - 53ms/epoch - 4ms/step
# 5/5 - 0s - loss: 366.0186 - mse: 366.0186 - 42ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 41.1399 - mse: 41.1399 - 38ms/epoch - 3ms/step
# 5/5 - 0s - loss: 56.3062 - mse: 56.3062 - 30ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 40.8552 - mse: 40.8552 - 37ms/epoch - 3ms/step
# 5/5 - 0s - loss: 55.7202 - mse: 55.7202 - 28ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 112.4462 - mse: 112.4462 - 42ms/epoch - 4ms/step
# 5/5 - 0s - loss: 112.9036 - mse: 112.9036 - 27ms/epoch - 5ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 162.2109 - mse: 162.2109 - 36ms/epoch - 3ms/step
# 5/5 - 0s - loss: 159.8641 - mse: 159.8641 - 36ms/epoch - 7ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 152.1924 - mse: 152.1924 - 48ms/epoch - 4ms/step
# 5/5 - 0s - loss: 165.6138 - mse: 165.6138 - 28ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 131.8009 - mse: 131.8009 - 41ms/epoch - 3ms/step
# 5/5 - 0s - loss: 147.9165 - mse: 147.9165 - 29ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 17.9377 - mse: 17.9377 - 39ms/epoch - 3ms/step
# 5/5 - 0s - loss: 30.8067 - mse: 30.8067 - 27ms/epoch - 5ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 18.8120 - mse: 18.8120 - 40ms/epoch - 3ms/step
# 5/5 - 0s - loss: 31.7731 - mse: 31.7731 - 56ms/epoch - 11ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 24.5842 - mse: 24.5842 - 41ms/epoch - 3ms/step
# 5/5 - 0s - loss: 33.1953 - mse: 33.1953 - 34ms/epoch - 7ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 27.7384 - mse: 27.7384 - 40ms/epoch - 3ms/step
# 5/5 - 0s - loss: 36.5618 - mse: 36.5618 - 34ms/epoch - 7ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 23.6196 - mse: 23.6196 - 52ms/epoch - 4ms/step
# 5/5 - 0s - loss: 30.6422 - mse: 30.6422 - 29ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 23.4159 - mse: 23.4159 - 39ms/epoch - 3ms/step
# 5/5 - 0s - loss: 31.5587 - mse: 31.5587 - 27ms/epoch - 5ms/step

# %%
# Рассмотрим 5-слойную сеть
fig = plt.figure(figsize=(30,20))
plt.subplots_adjust(wspace=0.1, hspace=0.5)
k = 0
for n in [8, 32, 128]:
  for f in ['relu', 'sigmoid', 'tanh']:
    k += 1
    for o in ['RMSprop', 'Adam']:
      n_layers.append(5)
      n_nums.append(n)
      act_func.append(f)
      opt.append(o)

      print(f'\nПараметры текущей нейронной сети: 5 слоёв, {n} нейронов, функция активации {f}, оптимизатор {o}...')

      inputs = Input(shape=(13,))
      x_1 = Flatten()(inputs)
      x_2 = Dense(n, activation=f)(x_1)
      x_3 = Dense(n, activation=f)(x_2)
      x_4 = Dense(n, activation=f)(x_3)
      outputs = Dense(1)(x_4)

      model = Model(inputs, outputs)

      model.compile(optimizer=o,
                    loss='mse',
                    metrics=['mse'])

      #model.summary()

      history = model.fit(X_train, y_train,
                    epochs=10,
                    batch_size=5,
                    validation_data=(X_test, y_test),
                    verbose=0)

      train_loss, train_m = model.evaluate(X_train, y_train, verbose=2)
      test_loss, test_m = model.evaluate(X_test, y_test, verbose=2)
      train_mse.append(train_m)
      test_mse.append(test_m)

      ax = fig.add_subplot(6, 2, k)
      ax.plot(history.history['val_mse'], label=f'val {o} {round(test_m,2)}')
      ax.plot(history.history['mse'], label=f'train {o} {round(train_m,2)}')
      ax.legend()
      ax.set_xlabel('epoch')
      ax.set_ylabel('mse')
      ax.set(title = f'Ошибка сети от эпох при {n} нейронах и функции активации {f}')
plt.show()
# Out:
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 81.2280 - mse: 81.2280 - 57ms/epoch - 5ms/step
# 5/5 - 0s - loss: 94.9441 - mse: 94.9441 - 45ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 31.0144 - mse: 31.0144 - 187ms/epoch - 16ms/step
# 5/5 - 0s - loss: 44.8611 - mse: 44.8611 - 170ms/epoch - 34ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 285.7048 - mse: 285.7048 - 38ms/epoch - 3ms/step
# 5/5 - 0s - loss: 264.6739 - mse: 264.6739 - 27ms/epoch - 5ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 367.0804 - mse: 367.0804 - 65ms/epoch - 5ms/step
# 5/5 - 0s - loss: 342.3705 - mse: 342.3705 - 49ms/epoch - 10ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 284.0874 - mse: 284.0874 - 40ms/epoch - 3ms/step
# 5/5 - 0s - loss: 263.2937 - mse: 263.2937 - 28ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 232.7093 - mse: 232.7093 - 69ms/epoch - 6ms/step
# 5/5 - 0s - loss: 214.8498 - mse: 214.8498 - 45ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 14.2499 - mse: 14.2499 - 37ms/epoch - 3ms/step
# 5/5 - 0s - loss: 23.7260 - mse: 23.7260 - 27ms/epoch - 5ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 10.8183 - mse: 10.8183 - 55ms/epoch - 5ms/step
# 5/5 - 0s - loss: 22.8770 - mse: 22.8770 - 49ms/epoch - 10ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 91.6923 - mse: 91.6923 - 40ms/epoch - 3ms/step
# 5/5 - 0s - loss: 86.8735 - mse: 86.8735 - 30ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 100.7489 - mse: 100.7489 - 37ms/epoch - 3ms/step
# 5/5 - 0s - loss: 93.9681 - mse: 93.9681 - 27ms/epoch - 5ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 56.3089 - mse: 56.3089 - 38ms/epoch - 3ms/step
# 5/5 - 0s - loss: 56.7569 - mse: 56.7569 - 28ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 60.6432 - mse: 60.6432 - 40ms/epoch - 3ms/step
# 5/5 - 0s - loss: 59.2519 - mse: 59.2519 - 29ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 12.3564 - mse: 12.3564 - 38ms/epoch - 3ms/step
# 5/5 - 0s - loss: 18.5372 - mse: 18.5372 - 27ms/epoch - 5ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 7.2578 - mse: 7.2578 - 38ms/epoch - 3ms/step
# 5/5 - 0s - loss: 15.8865 - mse: 15.8865 - 27ms/epoch - 5ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 35.1149 - mse: 35.1149 - 57ms/epoch - 5ms/step
# 5/5 - 0s - loss: 42.7679 - mse: 42.7679 - 44ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 53.9580 - mse: 53.9580 - 37ms/epoch - 3ms/step
# 5/5 - 0s - loss: 58.8100 - mse: 58.8100 - 28ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 11.0488 - mse: 11.0488 - 45ms/epoch - 4ms/step
# 5/5 - 0s - loss: 17.8717 - mse: 17.8717 - 33ms/epoch - 7ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 16.9510 - mse: 16.9510 - 39ms/epoch - 3ms/step
# 5/5 - 0s - loss: 22.7960 - mse: 22.7960 - 35ms/epoch - 7ms/step

# %%
# Рассмотрим 10-слойную сеть
fig = plt.figure(figsize=(30,20))
plt.subplots_adjust(wspace=0.1, hspace=0.5)
k = 0
for n in [8, 32, 128]:
  for f in ['relu', 'sigmoid', 'tanh']:
    k += 1
    for o in ['RMSprop', 'Adam']:
      n_layers.append(10)
      n_nums.append(n)
      act_func.append(f)
      opt.append(o)

      print(f'\nПараметры текущей нейронной сети: 10 слоёв, {n} нейронов, функция активации {f}, оптимизатор {o}...')

      inputs = Input(shape=(13,))
      x_1 = Flatten()(inputs)
      x_2 = Dense(n, activation=f)(x_1)
      x_3 = Dense(n, activation=f)(x_2)
      x_4 = Dense(n, activation=f)(x_3)
      x_5 = Dense(n, activation=f)(x_4)
      x_6 = Dense(n, activation=f)(x_5)
      x_7 = Dense(n, activation=f)(x_6)
      x_8 = Dense(n, activation=f)(x_7)
      x_9 = Dense(n, activation=f)(x_8)
      outputs = Dense(1)(x_9)

      model = Model(inputs, outputs)

      model.compile(optimizer=o,
                    loss='mse',
                    metrics=['mse'])

      #model.summary()

      history = model.fit(X_train, y_train,
                    epochs=10,
                    batch_size=5,
                    validation_data=(X_test, y_test),
                    verbose=0)

      train_loss, train_m = model.evaluate(X_train, y_train, verbose=2)
      test_loss, test_m = model.evaluate(X_test, y_test, verbose=2)
      train_mse.append(train_m)
      test_mse.append(test_m)

      ax = fig.add_subplot(6, 2, k)
      ax.plot(history.history['val_mse'], label=f'val {o} {round(test_m,2)}')
      ax.plot(history.history['mse'], label=f'train {o} {round(train_m,2)}')
      ax.legend()
      ax.set_xlabel('epoch')
      ax.set_ylabel('mse')
      ax.set(title = f'Ошибка сети от эпох при {n} нейронах и функции активации {f}')
plt.show()
# Out:
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 21.8482 - mse: 21.8482 - 45ms/epoch - 4ms/step
# 5/5 - 0s - loss: 34.3405 - mse: 34.3405 - 32ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 16.8670 - mse: 16.8670 - 40ms/epoch - 3ms/step
# 5/5 - 0s - loss: 30.3118 - mse: 30.3118 - 35ms/epoch - 7ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 366.2762 - mse: 366.2762 - 48ms/epoch - 4ms/step
# 5/5 - 0s - loss: 341.5209 - mse: 341.5209 - 30ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 371.3660 - mse: 371.3660 - 66ms/epoch - 6ms/step
# 5/5 - 0s - loss: 346.3971 - mse: 346.3971 - 76ms/epoch - 15ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 261.3596 - mse: 261.3596 - 42ms/epoch - 3ms/step
# 5/5 - 0s - loss: 241.5453 - mse: 241.5453 - 29ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 258.8478 - mse: 258.8478 - 42ms/epoch - 3ms/step
# 5/5 - 0s - loss: 239.1729 - mse: 239.1729 - 31ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 16.7407 - mse: 16.7407 - 44ms/epoch - 4ms/step
# 5/5 - 0s - loss: 26.8069 - mse: 26.8069 - 30ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 11.6480 - mse: 11.6480 - 53ms/epoch - 4ms/step
# 5/5 - 0s - loss: 22.1229 - mse: 22.1229 - 28ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 88.7239 - mse: 88.7239 - 39ms/epoch - 3ms/step
# 5/5 - 0s - loss: 84.9086 - mse: 84.9086 - 29ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 114.1088 - mse: 114.1088 - 41ms/epoch - 3ms/step
# 5/5 - 0s - loss: 105.4407 - mse: 105.4407 - 30ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 85.5475 - mse: 85.5475 - 42ms/epoch - 3ms/step
# 5/5 - 0s - loss: 83.1995 - mse: 83.1995 - 29ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 86.3231 - mse: 86.3231 - 41ms/epoch - 3ms/step
# 5/5 - 0s - loss: 83.5089 - mse: 83.5089 - 30ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 101.3410 - mse: 101.3410 - 61ms/epoch - 5ms/step
# 5/5 - 0s - loss: 89.8886 - mse: 89.8886 - 47ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 8.6967 - mse: 8.6967 - 42ms/epoch - 3ms/step
# 5/5 - 0s - loss: 15.5592 - mse: 15.5592 - 32ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 84.7647 - mse: 84.7647 - 41ms/epoch - 3ms/step
# 5/5 - 0s - loss: 83.7854 - mse: 83.7854 - 38ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 84.7658 - mse: 84.7658 - 61ms/epoch - 5ms/step
# 5/5 - 0s - loss: 83.7165 - mse: 83.7165 - 48ms/epoch - 10ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 24.7407 - mse: 24.7407 - 59ms/epoch - 5ms/step
# 5/5 - 0s - loss: 30.5015 - mse: 30.5015 - 47ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 22.2920 - mse: 22.2920 - 59ms/epoch - 5ms/step
# 5/5 - 0s - loss: 30.1138 - mse: 30.1138 - 44ms/epoch - 9ms/step

# %%
results['n_layers'] = n_layers
results['n_nums'] = n_nums
results['act_func'] = act_func
results['opt'] = opt
results['train_mse'] = train_mse
results['test_mse'] = test_mse
results['overtr_diff'] = results['test_mse'] - results['train_mse']

# %%
results.sort_values(by=['test_mse','overtr_diff'], ascending=[True, True])
# Out:
#     n_layers  n_nums act_func      opt   train_mse    test_mse  overtr_diff
# 49        10     128     relu     Adam    8.696736   15.559227     6.862491
# 31         5     128     relu     Adam    7.257773   15.886468     8.628695
# 34         5     128     tanh  RMSprop   11.048840   17.871668     6.822828
# 30         5     128     relu  RMSprop   12.356371   18.537237     6.180866
# 43        10      32     relu     Adam   11.647963   22.122866    10.474903
# 35         5     128     tanh     Adam   16.951048   22.796032     5.844984
# 25         5      32     relu     Adam   10.818292   22.877029    12.058738
# 24         5      32     relu  RMSprop   14.249891   23.726019     9.476128
# 42        10      32     relu  RMSprop   16.740726   26.806910    10.066183
# 53        10     128     tanh     Adam   22.292044   30.113773     7.821730
# 37        10       8     relu     Adam   16.867018   30.311800    13.444782
# 52        10     128     tanh  RMSprop   24.740704   30.501526     5.760822
# 16         3     128     tanh  RMSprop   23.619566   30.642248     7.022682
# 12         3     128     relu  RMSprop   17.937727   30.806679    12.868952
# 17         3     128     tanh     Adam   23.415859   31.558693     8.142834
# 13         3     128     relu     Adam   18.811983   31.773113    12.961130
# 14         3     128  sigmoid  RMSprop   24.584190   33.195259     8.611069
# 36        10       8     relu  RMSprop   21.848198   34.340508    12.492310
# 15         3     128  sigmoid     Adam   27.738413   36.561836     8.823423
# 32         5     128  sigmoid  RMSprop   35.114941   42.767933     7.652992
# 19         5       8     relu     Adam   31.014427   44.861073    13.846645
# 7          3      32     relu     Adam   40.855152   55.720215    14.865063
# 6          3      32     relu  RMSprop   41.139931   56.306152    15.166222
# 28         5      32     tanh  RMSprop   56.308857   56.756882     0.448025
# 33         5     128  sigmoid     Adam   53.958046   58.810028     4.851982
# 29         5      32     tanh     Adam   60.643250   59.251862    -1.391388
# 46        10      32     tanh  RMSprop   85.547523   83.199486    -2.348038
# 47        10      32     tanh     Adam   86.323082   83.508881    -2.814201
# 51        10     128  sigmoid     Adam   84.765839   83.716522    -1.049316
# 50        10     128  sigmoid  RMSprop   84.764694   83.785423    -0.979271
# 44        10      32  sigmoid  RMSprop   88.723854   84.908592    -3.815262
# 26         5      32  sigmoid  RMSprop   91.692314   86.873512    -4.818802
# 48        10     128     relu  RMSprop  101.341049   89.888634   -11.452415
# 27         5      32  sigmoid     Adam  100.748932   93.968056    -6.780876
# 18         5       8     relu  RMSprop   81.227966   94.944077    13.716110
# 45        10      32  sigmoid     Adam  114.108810  105.440735    -8.668076
# 8          3      32  sigmoid  RMSprop  112.446175  112.903587     0.457413
# 11         3      32     tanh     Adam  131.800903  147.916519    16.115616
# 9          3      32  sigmoid     Adam  162.210892  159.864136    -2.346756
# 10         3      32     tanh  RMSprop  152.192429  165.613815    13.421387
# 23         5       8     tanh     Adam  232.709290  214.849823   -17.859467
# 41        10       8     tanh     Adam  258.847809  239.172882   -19.674927
# 40        10       8     tanh  RMSprop  261.359650  241.545334   -19.814316
# 22         5       8     tanh  RMSprop  284.087372  263.293701   -20.793671
# 20         5       8  sigmoid  RMSprop  285.704773  264.673920   -21.030853
# 1          3       8     relu     Adam  286.936676  272.435547   -14.501129
# 0          3       8     relu  RMSprop  333.835144  320.776276   -13.058868
# 38        10       8  sigmoid  RMSprop  366.276184  341.520905   -24.755280
# 21         5       8  sigmoid     Adam  367.080383  342.370453   -24.709930
# 39        10       8  sigmoid     Adam  371.366028  346.397064   -24.968964
# 5          3       8     tanh     Adam  373.567444  366.018555    -7.548889
# 2          3       8  sigmoid  RMSprop  387.187988  368.292816   -18.895172
# 4          3       8     tanh  RMSprop  411.597809  400.847076   -10.750732
# 3          3       8  sigmoid     Adam  452.307983  427.830627   -24.477356

# %% [markdown]
# ### Выводы
# 1. Лучшее качество получилось на максимальном количестве слоев (10) и максимальном количестве нейронов (128). Обратное также прослеживается на графиках: чем меньше слоев и нейронов - тем больше ошибка.
# 2. Наименьшая ошибка получилась с оптимизатором Adam. Но в целом, RMSprop не сильно ему уступает.

# %% [markdown]
# Лушее качество получилось при [10,	128, relu,	Adam]: <br>
# То есть получили сравнительно небольшую ошибку, но довольно большое переобучение.<br>
# Получим предсказания модели для обех выборок:

# %%
inputs = Input(shape=(13,))
x_1 = Flatten()(inputs)
x_2 = Dense(128, activation='relu')(x_1)
x_3 = Dense(128, activation='relu')(x_2)
x_4 = Dense(128, activation='relu')(x_3)
x_5 = Dense(128, activation='relu')(x_4)
x_6 = Dense(128, activation='relu')(x_5)
x_7 = Dense(128, activation='relu')(x_6)
x_8 = Dense(128, activation='relu')(x_7)
x_9 = Dense(128, activation='relu')(x_8)
outputs = Dense(1)(x_9)

model = Model(inputs, outputs)

model.compile(optimizer='Adam',
                    loss='mse',
                    metrics=['mse'])

model.summary()

history = model.fit(X_train, y_train,
                    epochs=10,
                    batch_size=5,
                    validation_data=(X_test, y_test),
                    verbose=1)

train_loss, train_m = model.evaluate(X_train, y_train, verbose=2)
test_loss, test_m = model.evaluate(X_test, y_test, verbose=2)
# Out:
# Model: "model_54"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_55 (InputLayer)       [(None, 13)]              0
#
#  flatten_54 (Flatten)        (None, 13)                0
#
#  dense_270 (Dense)           (None, 128)               1792
#
#  dense_271 (Dense)           (None, 128)               16512
#
#  dense_272 (Dense)           (None, 128)               16512
#
#  dense_273 (Dense)           (None, 128)               16512
#
#  dense_274 (Dense)           (None, 128)               16512
#
#  dense_275 (Dense)           (None, 128)               16512
#
#  dense_276 (Dense)           (None, 128)               16512
#
#  dense_277 (Dense)           (None, 128)               16512
#
#  dense_278 (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 117,505
# Trainable params: 117,505
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 71/71 [==============================] - 3s 8ms/step - loss: 134.9727 - mse: 134.9727 - val_loss: 30.3486 - val_mse: 30.3486
# Epoch 2/10
# 71/71 [==============================] - 0s 5ms/step - loss: 30.4787 - mse: 30.4787 - val_loss: 37.5412 - val_mse: 37.5412
# Epoch 3/10
# 71/71 [==============================] - 0s 6ms/step - loss: 16.6729 - mse: 16.6729 - val_loss: 26.8129 - val_mse: 26.8129
# Epoch 4/10
# 71/71 [==============================] - 0s 6ms/step - loss: 13.9054 - mse: 13.9054 - val_loss: 21.8259 - val_mse: 21.8259
# Epoch 5/10
# 71/71 [==============================] - 0s 6ms/step - loss: 16.9707 - mse: 16.9707 - val_loss: 19.8966 - val_mse: 19.8966
# Epoch 6/10
# 71/71 [==============================] - 0s 6ms/step - loss: 9.8857 - mse: 9.8857 - val_loss: 17.3371 - val_mse: 17.3371
# Epoch 7/10
# 71/71 [==============================] - 0s 5ms/step - loss: 16.4780 - mse: 16.4780 - val_loss: 24.3586 - val_mse: 24.3586
# Epoch 8/10
# 71/71 [==============================] - 0s 6ms/step - loss: 11.2375 - mse: 11.2375 - val_loss: 16.2518 - val_mse: 16.2518
# Epoch 9/10
# 71/71 [==============================] - 0s 6ms/step - loss: 7.9978 - mse: 7.9978 - val_loss: 17.7102 - val_mse: 17.7102
# Epoch 10/10
# 71/71 [==============================] - 0s 6ms/step - loss: 7.7784 - mse: 7.7784 - val_loss: 15.3751 - val_mse: 15.3751
# 12/12 - 0s - loss: 7.5818 - mse: 7.5818 - 42ms/epoch - 3ms/step
# 5/5 - 0s - loss: 15.3751 - mse: 15.3751 - 27ms/epoch - 5ms/step

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)
# Out:
# 12/12 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step

# %%
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

print(f'Коэффициент детерминации на тренировочной выборке: {round(r2_train,2)}')
print(f'Коэффициент детерминации на тестовой выборке: {round(r2_test,2)}')
# Out:
# Коэффициент детерминации на тренировочной выборке: 0.91
# Коэффициент детерминации на тестовой выборке: 0.82

# %% [markdown]
# У нас получилось переобучение в 9%, что в целом, хорошо.

# %% [markdown]
# ### Общий вывод
# **Опишите, какого результата вы добились от нейросети? Что помогло вам улучшить ее точность?**<br>
# В итоге добились сравнительно неплохого качества модели. <br>
# Точность увеличивается с ростом числа слоев и числа нейронов. Но надо не забывать про переобучение.<br>
# Оптимизаторы и функции активации надо подбирать исходя из количества слоев и нейронов, так как разные значения показывают разное качество и нет ярко-выраженной зависимости. <br>
# Для задач регрессии больше подходят функции активации relu.<br>
